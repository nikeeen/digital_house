# %%
import numpy as np
import pandas as pd
import seaborn as sns
import re

# %%
data = pd.read_csv('../TP1/properatti.csv')
data_cruda = pd.read_csv('../TP1/properatti.csv')

# %% [markdown]
# # Trabajo práctico número 1

# %% [markdown]
# ## Para quedarnos solo con las columnas importantes

# %% [markdown]
# Nos quedamos solo con las columnas que aportan valor para estimar el precio del metro cuadrado

# %%
def eliminar_columnas(dataframe):
    dataframe = dataframe.drop(columns=['Unnamed: 0','operation','place_name','place_with_parent_names','country_name','geonames_id','lat-lon','lat','lon','floor','expenses','properati_url','image_thumbnail'])
    return dataframe

# %%
data = eliminar_columnas(data)
data.columns
# Out:
# Index(['property_type', 'state_name', 'price', 'currency',
#        'price_aprox_local_currency', 'price_aprox_usd', 'surface_total_in_m2',
#        'surface_covered_in_m2', 'price_usd_per_m2', 'price_per_m2', 'rooms',
#        'description', 'title'],
#       dtype='object')

# %% [markdown]
# ## Para quedarnos sólo con ARS y USD, eliminando los otros

# %% [markdown]
# Eliminamos las filas que tengan precios publicados en monedas que no sean pesos ni dolares

# %%
def eliminar_otras_currency(dataframe):
    mask_uyu = dataframe.currency == "UYU"
    mask_pen = dataframe.currency == "PEN"
    dataframe = dataframe.drop(data.currency[mask_uyu].index)
    dataframe = dataframe.drop(data.currency[mask_pen].index)
    return dataframe

# %%
data = eliminar_otras_currency(data)
data.currency.value_counts()
# Out:
# USD    87587
# ARS    13219
# Name: currency, dtype: int64

# %%
data.property_type.value_counts()
# Out:
# apartment    71063
# house        40267
# PH            5751
# store         4136
# Name: property_type, dtype: int64

# %% [markdown]
# ## Para quedarnos solo apartment y house

# %% [markdown]
# Eliminamos las filas que no contengan apartment y house, debido a que los demás hay pocos registros en proporcion a los que hay en apartment y house

# %%
def eliminar_ph_y_store(dataframe):
    dataframe = dataframe.drop(dataframe.loc[dataframe.property_type == 'PH'].index)
    dataframe = dataframe.drop(dataframe.loc[dataframe.property_type == 'store'].index)
    return dataframe

# %%
data = eliminar_ph_y_store(data)
data.property_type.value_counts()
# Out:
# apartment    71063
# house        40267
# Name: property_type, dtype: int64

# %% [markdown]
# ## Para quedarnos solo con >1000 publicaciones por ciudad

# %% [markdown]
# Nos quedamos con los registros que pertenezcan a ciudades donde haya al menos mas de 1000 publicaciones ya que el resto no es un numero que estimamos suficiente para realizar una estimación adecuada

# %%
def solo_mayores_a_mil(dataframe):
    cantidad_de_publicaciones = 1000
    lista = list((dataframe['state_name'].value_counts()>1000)[dataframe['state_name'].value_counts()>cantidad_de_publicaciones].index)
    dataframe = dataframe[dataframe['state_name'].isin(lista)]
    return dataframe

# %%
data = solo_mayores_a_mil(data)
data.state_name.value_counts()
# Out:
# Capital Federal                 32316
# Bs.As. G.B.A. Zona Norte        25560
# Bs.As. G.B.A. Zona Sur          13952
# Córdoba                         12069
# Santa Fe                        10172
# Buenos Aires Costa Atlántica    10006
# Bs.As. G.B.A. Zona Oeste         9322
# Buenos Aires Interior            2291
# Name: state_name, dtype: int64

# %% [markdown]
# ## (1) Separar la columna 'place_with_parent_names'
# Esto es para tener la ubicación precisa de cada vivienda en una sola columna. Se toma únicamente el tercer segmento del string separados por `|` de la columna `place_with_parent_names`. En los que esta información no exista, se completará con la columna `place_name`

# %%
def separar_columna_place_with_parent_names(dataframe):
    '''Esta función toma la tercera parte de la columna 'place_with_parent_names' y si no tiene esa parte, completa con la columna 'place_name'''
    separado = dataframe['place_with_parent_names'].str.split(pat='|', n=-1, expand=True)
    indice = ['index','pais','region','ciudad','barrio','detalle1','detalle2']
    separado.columns = indice
    mask = separado.ciudad == ''
    separado.ciudad[mask] = np.NaN
    dataframe['ciudad_separada'] = separado['ciudad']
    dataframe.ciudad_separada[dataframe.ciudad_separada.isnull()] = dataframe.place_name[dataframe.ciudad_separada.isnull()]
    return dataframe

# %%
data = data_grouped.filter(lambda grp: grp["state_name"].isin(lista))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11844/1792427431.py in <module>
# ----> 1 data = data_grouped.filter(lambda grp: grp["state_name"].isin(lista))
#
# ~\anaconda3\envs\dhdsblend2021\lib\site-packages\pandas\core\groupby\generic.py in filter(self, func, dropna, *args, **kwargs)
#    1590             else:
#    1591                 # non scalars aren't allowed
# -> 1592                 raise TypeError(
#    1593                     f"filter function returned a {type(res).__name__}, "
#    1594                     "but expected a scalar bool"
#
# TypeError: filter function returned a Series, but expected a scalar bool

# %% [markdown]
# ## (2) Limpieza e imputación de precios
#
# Jerarquía de imputación
#
# a) Dato directo del precio /m2 en dólares
#
# b) Tomar precio de /m2 en pesos (analizado y descartado)
#
# c) Inferir precio con precio total / superficie
#
# d) Imputar por media según zona y tipo de propiedad

# %% [markdown]
# ### (a) Dato directo del precio /m2 en dólares

# %%
data['state_name'].nlargest(n=10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11844/4293553991.py in <module>
# ----> 1 data['state_name'].nlargest(n=10)
#
# ~\anaconda3\envs\dhdsblend2021\lib\site-packages\pandas\core\series.py in nlargest(self, n, keep)
#    3647         dtype: int64
#    3648         """
# -> 3649         return algorithms.SelectNSeries(self, n=n, keep=keep).nlargest()
#    3650
#    3651     def nsmallest(self, n=5, keep="first") -> "Series":
#
# ~\anaconda3\envs\dhdsblend2021\lib\site-packages\pandas\core\algorithms.py in nlargest(self)
#    1156
#    1157     def nlargest(self):
# -> 1158         return self.compute("nlargest")
#    1159
#    1160     def nsmallest(self):
#
# ~\anaconda3\envs\dhdsblend2021\lib\site-packages\pandas\core\algorithms.py in compute(self, method)
#    1192         dtype = self.obj.dtype
#    1193         if not self.is_valid_dtype_n_method(dtype):
# -> 1194             raise TypeError(f"Cannot use method '{method}' with dtype {dtype}")
#    1195
#    1196         if n <= 0:
#
# TypeError: Cannot use method 'nlargest' with dtype object

# %% [markdown]
# La columna `price_usd_per_m2` contiene directamente el valor del metro cuadrado de cada propiedad medida en dólares. Se toma de forma directa.

# %%
data.state_name.value_counts()
# Out:
# Capital Federal                 32316
# Bs.As. G.B.A. Zona Norte        25560
# Bs.As. G.B.A. Zona Sur          13952
# Córdoba                         12069
# Santa Fe                        10172
# Buenos Aires Costa Atlántica    10006
# Bs.As. G.B.A. Zona Oeste         9322
# Buenos Aires Interior            2291
# Name: state_name, dtype: int64

# %%
def transformar_columna_precio_m2(dataframe):
    '''Esta función transforma la columna 'price_usd_per_m2' en la columna 'precio_unificado' '''
    dataframe['precio_unificado'] = dataframe.loc[data.price_usd_per_m2.notnull()]['price_usd_per_m2']
    return dataframe

# %% [markdown]
# La siguiente función es sólo a modo de referencia y no está incluida en el final como parte del proceso, y cuenta el porcentaje de filas completas de la columna `price_usd_per_m2`

# %%
def contar_transformar_columna_precio_m2(dataframe):
    '''Esta función contabiliza la cantidad de filas no nulas en la columna 'price_usd_per_m2' '''
    print1 = (dataframe['price_usd_per_m2'].notnull().sum() / dataframe.shape[0] *100).round(2)
    return print1

# %%
print("Cant. de datos en 'price_usd_per_m2':   %", contar_transformar_columna_precio_m2(data))
# Out:
# Cant. de datos en 'price_usd_per_m2':   % 56.61

# %% [markdown]
# ### (b) Tomar precio de /m2 en pesos (descartado, leer el por qué)

# %% [markdown]
# Primero, es necesario saber la conversión del tipo de cambio de dólar respecto al peso. Para esto mismo, se calculará el promedio del precio en USD y del precio en $ de todas las filas no nulas que contengan ambos valores.

# %% [markdown]
# En esta primera función, se estima la media del tipo de cambio entre el precio en pesos y el precio en dólares, las columnas `price_aprox_local_currency` / `price_aprox_usd`

# %%
def estimar_tipo_de_cambio(dataframe):
    '''Esta función estima el tipo de cambio promedio entre 'price_aprox_local_currency' y 'price_aprox_usd'  '''
    mask_tipo_de_cambio = (data['price_aprox_local_currency'].notnull() & data['price_aprox_usd'].notnull())
    calculo_tipo_de_cambio = data.loc[mask_tipo_de_cambio, 'price_aprox_local_currency'] / data.loc[mask_tipo_de_cambio, 'price_aprox_usd']
    tipo_de_cambio = calculo_tipo_de_cambio.mean()
    valor = (tipo_de_cambio).round(2)
    return valor

# %%
print("Tipo de cambio promedio entre entre 'price_aprox_local_currency' y 'price_aprox_usd': ", estimar_tipo_de_cambio(data), "$/USD ")
# Out:
# Tipo de cambio promedio entre entre 'price_aprox_local_currency' y 'price_aprox_usd':  17.64 $/USD

# %% [markdown]
# Para comparar este dato, se toma el valor del dólar de ese entonces, primer semestre de 2017.  Por esto mismo, para hacer la conversión del tipo de cambio dólar / peso se hace un promedio entre la primera cotización del semestre y la última, a saber:
#
# 02-01-2017: 16.3 $ / USD
#
# 30-06-2017: 16.87 $ / USD
#
# Tomando el promedio de 16.59 $ / USD, está cercano al valor de  17.64 obtenido antes, por lo tanto es un dato aceptable

# %% [markdown]
# Por lo tanto, podría hacer esta misma comprobación con las columnas que miden el precio por metro cuadrado para ver si la columna `price_per_m2` que está medida en pesos es confiable. De la misma manera que antes se calcula

# %%
def estimar_tipo_de_cambio_segun_m2(dataframe):
    '''Esta función estima el tipo de cambio promedio entre 'price_per_m2' y 'price_usd_per_m2' '''
    mask_cambio = (dataframe['price_per_m2'].notnull() & dataframe['price_usd_per_m2'].notnull())
    prueba = dataframe.loc[mask_cambio, 'price_per_m2'] / dataframe.loc[mask_cambio, 'price_usd_per_m2']
    print1 = (prueba.mean()).round(2)
    return print1

# %%
print("Tipo de cambio promedio entre entre 'price_per_m2' y 'price_usd_per_m2': ", estimar_tipo_de_cambio_segun_m2(data), "$/USD")
# Out:
# Tipo de cambio promedio entre entre 'price_per_m2' y 'price_usd_per_m2':  5.87 $/USD

# %% [markdown]
# Como se puede ver, este valor está muy lejano al tipo de cambio real, por lo que no pueden tomarse los datos de la columna `price_per_m2` como ciertos, por lo que se descarta usar esta fuente de datos.

# %% [markdown]
# ### (c) Inferir precio con precio total / superficie

# %% [markdown]
# Otra manera de obtener el precio del m2 es dividiendo el precio publicado por la superficie de la propiedad.

# %% [markdown]
# Primero es necesario unificar las columnas `surface_total_in_m2` y `surface_covered_in_m2` con los siguientes criterios:
#
#    - Si surface_total tiene DATO y surface_covered tiene NAN -> tomo dato
#
#    - Si surface_total tiene NAN y surface_covered tiene DATO -> tomo dato
#
#    - Si surface_total tiene DATO y surface_covered tiene DATO -> tomo el mayor
#
#        - Si surface_total < surface_covered -> tomo surface_covered (caso sin sentido, por eso tomo el mayor)
#
#    - Si surface_total > surface_covered -> tomo surface_total (caso coherente)
#
#    - Si surface_total == surface_covered -> tomo surface_total (caso coherente)

# %%
def limpiar_superficies(dataframe):
    '''Esta función unifica las columnas 'surface_total_in_m2' y 'surface_covered_in_m2' en la columna 'superficie_unica' 
    con el siguiente criterio:
    - si surface_total DATO y surface_covered NAN -> tomo dato
    - si surface_total NAN y surface_covered DATO -> tomo dato
    - si surface_total DATO y surface_covered DATO -> tomo el mayor
        - Si surface_total < surface_covered -> tomo surface_covered (caso sin sentido, por eso tomo el mayor)
    - Si surface_total > surface_covered -> tomo surface_total (caso coherente)
    - Si surface_total == surface_covered -> tomo surface_total (caso coherente)'''
    #surface_total DATO y surface_covered NAN -> tomo dato
    mask_surfaces_sin_cubierta = (dataframe['surface_total_in_m2'].notnull() & dataframe['surface_covered_in_m2'].isnull())
    dataframe.loc[mask_surfaces_sin_cubierta,'superficie_unificada'] = dataframe.loc[mask_surfaces_sin_cubierta, 'surface_total_in_m2']

    #surface_total NAN y surface_covered DATO -> tomo dato
    mask_surfaces_sin_total = (dataframe['surface_total_in_m2'].isnull() & dataframe['surface_covered_in_m2'].notnull())
    dataframe.loc[mask_surfaces_sin_total,'superficie_unificada'] = dataframe.loc[mask_surfaces_sin_total, 'surface_covered_in_m2']

    #surface_total DATO y surface_covered DATO -> tomo el mayor
    #Si surface_total < surface_covered -> tomo surface_covered (caso sin sentido, por eso tomo el mayor)
    mask_surfaces_covered_mayor = (dataframe['surface_covered_in_m2'] > dataframe['surface_total_in_m2'])
    dataframe.loc[mask_surfaces_covered_mayor,'superficie_unificada'] = dataframe.loc[mask_surfaces_covered_mayor, 'surface_covered_in_m2']

    #Si surface_total > surface_covered -> tomo surface_total (caso coherente)
    mask_surfaces_total_mayor = (dataframe['surface_covered_in_m2'] < dataframe['surface_total_in_m2'])
    dataframe.loc[mask_surfaces_total_mayor,'superficie_unificada'] = dataframe.loc[mask_surfaces_total_mayor, 'surface_total_in_m2']

    #Si surface_total == surface_covered -> tomo surface_total (caso coherente)
    mask_surfaces_iguales = (dataframe['surface_covered_in_m2'] == dataframe['surface_total_in_m2'])
    dataframe.loc[mask_surfaces_iguales,'superficie_unificada'] = dataframe.loc[mask_surfaces_iguales, 'surface_total_in_m2']
    
    #Si superficie_unificada == 0 -> pongo NaN
    mask_surfaces_cero = dataframe['superficie_unificada'] == 0
    dataframe.loc[mask_surfaces_cero,'superficie_unificada'] = np.NaN
    return dataframe

# %% [markdown]
# La siguiente función es sólo a modo de referencia y no está incluida en el final como parte del proceso, y contabiliza el proceso de limpieza de ambas columnas de superficies

# %%
def contar_limpiar_superficies(dataframe):
    '''Esta función contabiliza los registros de la función limpiar_superficies '''
    #surface_total DATO y surface_covered NAN -> tomo dato
    mask_surfaces_sin_cubierta = (dataframe['surface_total_in_m2'].notnull() & dataframe['surface_covered_in_m2'].isnull())
    print1 = print("Cantidad de filas sin superficie cubierta y con superficie total: ", mask_surfaces_sin_cubierta.sum())
    dataframe.loc[mask_surfaces_sin_cubierta,'superficie_unificada'] = dataframe.loc[mask_surfaces_sin_cubierta, 'surface_total_in_m2']

    #surface_total NAN y surface_covered DATO -> tomo dato
    mask_surfaces_sin_total = (dataframe['surface_total_in_m2'].isnull() & dataframe['surface_covered_in_m2'].notnull())
    print2 = print("Cantidad de filas con superficie cubierta y sin superficie total: ", mask_surfaces_sin_total.sum())
    dataframe.loc[mask_surfaces_sin_total,'superficie_unificada'] = dataframe.loc[mask_surfaces_sin_total, 'surface_covered_in_m2']

    #surface_total DATO y surface_covered DATO -> tomo el mayor
    #Si surface_total < surface_covered -> tomo surface_covered (caso sin sentido, por eso tomo el mayor)
    mask_surfaces_covered_mayor = (dataframe['surface_covered_in_m2'] > dataframe['surface_total_in_m2'])
    print3 = print("Cantidad de filas con superficie cubierta mayor a superficie total: ", mask_surfaces_covered_mayor.sum())
    dataframe.loc[mask_surfaces_covered_mayor,'superficie_unificada'] = dataframe.loc[mask_surfaces_covered_mayor, 'surface_covered_in_m2']

    #Si surface_total > surface_covered -> tomo surface_total (caso coherente)
    mask_surfaces_total_mayor = (dataframe['surface_covered_in_m2'] < dataframe['surface_total_in_m2'])
    print4 = print("Cantidad de filas con superficie total mayor a superficie covered: ", mask_surfaces_total_mayor.sum())
    dataframe.loc[mask_surfaces_total_mayor,'superficie_unificada'] = dataframe.loc[mask_surfaces_total_mayor, 'surface_total_in_m2']

    #Si surface_total == surface_covered -> tomo surface_total (caso coherente)
    mask_surfaces_iguales = (dataframe['surface_covered_in_m2'] == dataframe['surface_total_in_m2'])
    print5 = print("Cantidad de filas con superficies iguales: ", mask_surfaces_iguales.sum())
    dataframe.loc[mask_surfaces_iguales,'superficie_unificada'] = dataframe.loc[mask_surfaces_iguales, 'surface_total_in_m2']
    return print1, print2, print3, print4, print5

# %%
data_cruda_contador_limpieza = separar_columna_place_with_parent_names(data_cruda)
data_cruda_contador_limpieza = transformar_columna_precio_m2(data_cruda_contador_limpieza)
contar_limpiar_superficies(data_cruda_contador_limpieza);
# Out:
# Cantidad de filas sin superficie cubierta y con superficie total:  7538
# Cantidad de filas con superficie cubierta y sin superficie total:  26959
# Cantidad de filas con superficie cubierta mayor a superficie total:  1106
# Cantidad de filas con superficie total mayor a superficie covered:  49075
# Cantidad de filas con superficies iguales:  24173
# C:\Users\magan\AppData\Local\Temp/ipykernel_23200/1091634724.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe.ciudad_separada[dataframe.ciudad_separada.isnull()] = dataframe.place_name[dataframe.ciudad_separada.isnull()]

# %% [markdown]
# Luego, tomo aquellas filas que tengan precio y superficie (limpia), la divido y completo el precio por metro cuadrado

# %%
def completar_precio_dividiendo_superficie(dataframe):
    '''Esta función rellena 'precio_unificado' dividiendo el precio por la superficie en los registros no nulos de ambos y nulo en el precio_unificado 
    Esta función va luego de limpiar_superficies'''
    mask1 = dataframe['price'].notnull()
    mask2 = dataframe['superficie_unificada'].notnull()
    mask3 = dataframe['precio_unificado'].isnull()
    mask_criterios = (mask1 & mask2 & mask3)
    #print("La cantidad de registros con precio y superficie y sin precio unificado son: ",mask_criterios.sum())
    dataframe.loc[mask_criterios, 'precio_unificado'] = (dataframe['price'] / dataframe['superficie_unificada'])
    return dataframe

# %% [markdown]
# La siguiente función es sólo a modo de referencia y no está incluida en el final como parte del proceso, y contabiliza el proceso de precios completados obtenidos por la división entre precio / superficie.

# %%
def contar_completar_precio_dividiendo_superficie(dataframe):
    '''Esta función cuenta la cantidad de filas con criterio AND
    - 'price' no nulos
    - 'superficie_unificada' no nulos
    - 'precio_unificado' nulos. Esto es porque los voy a obtener por division de los dos anteriores
    NOTA: esta función va luego de limpiar_superficies()'''
    mask1 = dataframe['price'].notnull()
    mask2 = dataframe['superficie_unificada'].notnull()
    mask3 = dataframe['precio_unificado'].isnull()
    mask_criterios = (mask1 & mask2 & mask3)
    print1 = print("La cantidad de registros con precio y con superficie y sin precio unificado (NaN) son: ", mask_criterios.sum())
    return print1

# %%
data_cruda_precio_superficie = separar_columna_place_with_parent_names(data_cruda)
data_cruda_precio_superficie = transformar_columna_precio_m2(data_cruda_precio_superficie)
data_cruda_precio_superficie = limpiar_superficies(data_cruda_precio_superficie)
contar_completar_precio_dividiendo_superficie(data_cruda_precio_superficie)
# Out:
# La cantidad de registros con precio y con superficie y sin precio unificado (NaN) son:  24308
# C:\Users\magan\AppData\Local\Temp/ipykernel_23200/1091634724.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe.ciudad_separada[dataframe.ciudad_separada.isnull()] = dataframe.place_name[dataframe.ciudad_separada.isnull()]

# %% [markdown]
# ### (d) Imputar por media según zona y tipo de propiedad

# %% [markdown]
# Como última instancia, para obtener la mayor cantidad de campos `precio_unificado` completos, se imputan de la siguiente manera:
# - Primero se agrupa por tipo de propiedad y ciudad.
# - Se calcula el promedio por cada agrupación
# - Se imputa a los que tengan NaN en `precio_unificado` y tengan datos en ciudad y tipo de propiedad

# %%
def imputar_por_ciudad_y_tipo(dataframe):
    '''Esta función imputa los NaN de 'precio_unificado' tomando como criterio la media de 'ciudad_separada' & 'property_type' 
    Es decir, no imputa por media general de todas las filas, sino por ejemplo la media de los precios de apartment de Córdoba o 
    la media de house de Villa Luro'''
    not_null_mask = np.logical_and(dataframe.ciudad_separada.notnull(), dataframe.property_type.notnull())
    procesar = dataframe.loc[not_null_mask, :]
    promedio_a_imputar = procesar.groupby(['ciudad_separada','property_type'])
    data_filled = promedio_a_imputar['precio_unificado'].transform(lambda grp: grp.fillna(grp.mean()))
    mask_a_imputar = dataframe.precio_unificado.isnull()
    dataframe.loc[mask_a_imputar,'precio_unificado'] = data_filled[mask_a_imputar]
    #dataframe.precio_unificado.isnull().sum()
    return dataframe

# %% [markdown]
# La siguiente función es sólo a modo de referencia y no está incluida en el final como parte del proceso, y contabiliza el proceso de imputación con el criterio anterior.

# %%
def contar_imputar_por_ciudad_y_tipo(dataframe):
    '''Esta función cuenta los NaN de 'precio_unificado' antes y después de aplicar la función imputar_por_ciudad_y_tipo()'''   
    nan_iniciales = dataframe.precio_unificado.isnull().sum()
    print1 = print("La cantidad de NaN iniciales en el dataframe sin imputar son: ", nan_iniciales)
    not_null_mask = np.logical_and(dataframe.ciudad_separada.notnull(), dataframe.property_type.notnull())
    procesar = dataframe.loc[not_null_mask, :]
    promedio_a_imputar = procesar.groupby(['ciudad_separada','property_type'])
    data_filled = promedio_a_imputar['precio_unificado'].transform(lambda grp: grp.fillna(grp.mean()))
    mask_a_imputar = dataframe.precio_unificado.isnull()
    dataframe.loc[mask_a_imputar,'precio_unificado'] = data_filled[mask_a_imputar]
    print2 = print("La cantidad de datos completados son: ", (nan_iniciales - dataframe.precio_unificado.isnull().sum()))
    print3 = print("La cantidad de NaN en 'precio_unificado' quedaron en: ", dataframe.precio_unificado.isnull().sum())
    return print1, print2, print3

# %% [markdown]
# Contabilizadores de esta operación

# %%
data_cruda_imputacion = separar_columna_place_with_parent_names(data_cruda)
data_cruda_imputacion = transformar_columna_precio_m2(data_cruda_imputacion)
data_cruda_imputacion = limpiar_superficies(data_cruda_imputacion)
data_cruda_imputacion = completar_precio_dividiendo_superficie(data_cruda_imputacion)
contar_imputar_por_ciudad_y_tipo(data_cruda_imputacion);
# Out:
# C:\Users\magan\AppData\Local\Temp/ipykernel_23200/1091634724.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe.ciudad_separada[dataframe.ciudad_separada.isnull()] = dataframe.place_name[dataframe.ciudad_separada.isnull()]
# La cantidad de NaN iniciales en el dataframe sin imputar son:  28295
# La cantidad de datos completados son:  27771
# La cantidad de NaN en 'precio_unificado' quedaron en:  524

# %% [markdown]
# ## Ejecución de todas las funciones y dataframe final

# %%
data = pd.read_csv('../TP1/properatti.csv')
salida_1 = separar_columna_place_with_parent_names(data)
salida_2 = transformar_columna_precio_m2(salida_1)
salida_3 = limpiar_superficies(salida_2)
salida_4 = completar_precio_dividiendo_superficie(salida_3)
salida_5 = imputar_por_ciudad_y_tipo(salida_4)
salida_5.sample(50)
# Out:
# C:\Users\magan\AppData\Local\Temp/ipykernel_23200/1091634724.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe.ciudad_separada[dataframe.ciudad_separada.isnull()] = dataframe.place_name[dataframe.ciudad_separada.isnull()]
#         Unnamed: 0 operation property_type                  place_name  \
# 26456        26456      sell     apartment                     Almagro
# 63200        63200      sell         house                     Rosario
# 34926        34926      sell     apartment       Buenos Aires Interior
# 59181        59181      sell     apartment                   Caballito
# 14572        14572      sell     apartment                     Palermo
# 42203        42203      sell     apartment                       Pilar
# 41629        41629      sell         house                     Posadas
# 104289      104289      sell            PH             Lomas de Zamora
# 55981        55981      sell     apartment                    Belgrano
# 108633      108633      sell            PH                    La Plata
# 37003        37003      sell     apartment                     Liniers
# 50063        50063      sell            PH                    La Plata
# 71754        71754      sell     apartment            Villa del Parque
# 100612      100612      sell         house                    Martínez
# 467            467      sell         house                    Santa Fe
# 64961        64961      sell     apartment                     Córdoba
# 97696        97696      sell     apartment                    Nordelta
# 92022        92022      sell     apartment                       Morón
# 9532          9532      sell         house               Mar del Plata
# 115370      115370      sell     apartment                     Córdoba
# 119538      119538      sell         house           Mar de las Pampas
# 69900        69900      sell         house                     Adrogué
# 71259        71259      sell         house             Valeria del Mar
# 94664        94664      sell            PH                     Palermo
# 97469        97469      sell     apartment                   Mburucuyá
# 109626      109626      sell     apartment                      Olivos
# 82849        82849      sell     apartment                    La Plata
# 53761        53761      sell         house               Mar del Plata
# 61609        61609      sell         house              Los Polvorines
# 78263        78263      sell         house                       Muñiz
# 38515        38515      sell     apartment               Villa Urquiza
# 47710        47710      sell         house  La Escondida de Manzanares
# 24486        24486      sell         house                    Martínez
# 74763        74763      sell         house                       Lobos
# 86508        86508      sell     apartment                    Del Viso
# 99997        99997      sell     apartment            Villa del Parque
# 105072      105072      sell         house                     Adrogué
# 99629        99629      sell     apartment                     Rosario
# 32922        32922      sell         store                   Mataderos
# 98464        98464      sell     apartment                     Rosario
# 18404        18404      sell         house               Mar del Plata
# 67746        67746      sell         house                     Córdoba
# 70516        70516      sell         house            Solar del Bosque
# 56906        56906      sell     apartment               Mar del Plata
# 74199        74199      sell         house                     Burzaco
# 32775        32775      sell     apartment                     Rosario
# 38912        38912      sell     apartment                   Mataderos
# 121035      121035      sell     apartment                    Belgrano
# 40168        40168      sell         house               Mar del Plata
# 54463        54463      sell         house                   Benavidez
#
#                                   place_with_parent_names country_name  \
# 26456                 |Argentina|Capital Federal|Almagro|    Argentina
# 63200                        |Argentina|Santa Fe|Rosario|    Argentina
# 34926                   |Argentina|Buenos Aires Interior|    Argentina
# 59181               |Argentina|Capital Federal|Caballito|    Argentina
# 14572                 |Argentina|Capital Federal|Palermo|    Argentina
# 42203          |Argentina|Bs.As. G.B.A. Zona Norte|Pilar|    Argentina
# 41629                        |Argentina|Misiones|Posadas|    Argentina
# 104289  |Argentina|Bs.As. G.B.A. Zona Sur|Lomas de Zam...    Argentina
# 55981                |Argentina|Capital Federal|Belgrano|    Argentina
# 108633  |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|La ...    Argentina
# 37003                 |Argentina|Capital Federal|Liniers|    Argentina
# 50063   |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|La ...    Argentina
# 71754        |Argentina|Capital Federal|Villa del Parque|    Argentina
# 100612  |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...    Argentina
# 467                         |Argentina|Santa Fe|Santa Fe|    Argentina
# 64961                         |Argentina|Córdoba|Córdoba|    Argentina
# 97696   |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Nord...    Argentina
# 92022    |Argentina|Bs.As. G.B.A. Zona Oeste|Morón|Morón|    Argentina
# 9532    |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 115370                        |Argentina|Córdoba|Córdoba|    Argentina
# 119538  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 69900   |Argentina|Bs.As. G.B.A. Zona Sur|Almirante Br...    Argentina
# 71259   |Argentina|Buenos Aires Costa Atlántica|Valeri...    Argentina
# 94664                 |Argentina|Capital Federal|Palermo|    Argentina
# 97469                    |Argentina|Corrientes|Mburucuyá|    Argentina
# 109626  |Argentina|Bs.As. G.B.A. Zona Norte|Vicente Ló...    Argentina
# 82849         |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 53761   |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 61609   |Argentina|Bs.As. G.B.A. Zona Norte|Malvinas A...    Argentina
# 78263   |Argentina|Bs.As. G.B.A. Zona Norte|San Miguel...    Argentina
# 38515           |Argentina|Capital Federal|Villa Urquiza|    Argentina
# 47710   |Argentina|Bs.As. G.B.A. Zona Norte|Pilar|La E...    Argentina
# 24486   |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...    Argentina
# 74763       |Argentina|Buenos Aires Interior|Lobos|Lobos|    Argentina
# 86508   |Argentina|Bs.As. G.B.A. Zona Norte|Pilar|Del ...    Argentina
# 99997        |Argentina|Capital Federal|Villa del Parque|    Argentina
# 105072  |Argentina|Bs.As. G.B.A. Zona Sur|Almirante Br...    Argentina
# 99629                        |Argentina|Santa Fe|Rosario|    Argentina
# 32922               |Argentina|Capital Federal|Mataderos|    Argentina
# 98464                        |Argentina|Santa Fe|Rosario|    Argentina
# 18404   |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 67746                                 |Argentina|Córdoba|    Argentina
# 70516   |Argentina|Bs.As. G.B.A. Zona Sur|Ezeiza|Solar...    Argentina
# 56906   |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 74199   |Argentina|Bs.As. G.B.A. Zona Sur|Almirante Br...    Argentina
# 32775                        |Argentina|Santa Fe|Rosario|    Argentina
# 38912               |Argentina|Capital Federal|Mataderos|    Argentina
# 121035               |Argentina|Capital Federal|Belgrano|    Argentina
# 40168   |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 54463   |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Bena...    Argentina
#
#                           state_name  geonames_id  \
# 26456                Capital Federal    3436397.0
# 63200                       Santa Fe    3838574.0
# 34926          Buenos Aires Interior    3435907.0
# 59181                Capital Federal    3435874.0
# 14572                Capital Federal    3430234.0
# 42203       Bs.As. G.B.A. Zona Norte    3429979.0
# 41629                       Misiones    3429886.0
# 104289        Bs.As. G.B.A. Zona Sur    3431270.0
# 55981                Capital Federal    3436077.0
# 108633        Bs.As. G.B.A. Zona Sur    3432039.0
# 37003                Capital Federal    3431333.0
# 50063         Bs.As. G.B.A. Zona Sur    3432039.0
# 71754                Capital Federal    3427455.0
# 100612      Bs.As. G.B.A. Zona Norte    3430813.0
# 467                         Santa Fe    3836277.0
# 64961                        Córdoba    3860259.0
# 97696       Bs.As. G.B.A. Zona Norte          NaN
# 92022       Bs.As. G.B.A. Zona Oeste    3430544.0
# 9532    Buenos Aires Costa Atlántica    3430863.0
# 115370                       Córdoba    3860259.0
# 119538  Buenos Aires Costa Atlántica          NaN
# 69900         Bs.As. G.B.A. Zona Sur          NaN
# 71259   Buenos Aires Costa Atlántica    3427561.0
# 94664                Capital Federal    3430234.0
# 97469                     Corrientes    3430759.0
# 109626      Bs.As. G.B.A. Zona Norte    3430310.0
# 82849         Bs.As. G.B.A. Zona Sur    3432039.0
# 53761   Buenos Aires Costa Atlántica    3430863.0
# 61609       Bs.As. G.B.A. Zona Norte          NaN
# 78263       Bs.As. G.B.A. Zona Norte    3430513.0
# 38515                Capital Federal    3433775.0
# 47710       Bs.As. G.B.A. Zona Norte          NaN
# 24486       Bs.As. G.B.A. Zona Norte    3430813.0
# 74763          Buenos Aires Interior    3431309.0
# 86508       Bs.As. G.B.A. Zona Norte    3435087.0
# 99997                Capital Federal    3427455.0
# 105072        Bs.As. G.B.A. Zona Sur          NaN
# 99629                       Santa Fe    3838574.0
# 32922                Capital Federal    3430787.0
# 98464                       Santa Fe    3838574.0
# 18404   Buenos Aires Costa Atlántica    3430863.0
# 67746                        Córdoba    3860255.0
# 70516         Bs.As. G.B.A. Zona Sur          NaN
# 56906   Buenos Aires Costa Atlántica    3430863.0
# 74199         Bs.As. G.B.A. Zona Sur    3435894.0
# 32775                       Santa Fe    3838574.0
# 38912                Capital Federal    3430787.0
# 121035               Capital Federal    3436077.0
# 40168   Buenos Aires Costa Atlántica    3430863.0
# 54463       Bs.As. G.B.A. Zona Norte    3436048.0
#
#                               lat-lon        lat  ...  floor  rooms expenses  \
# 26456                             NaN        NaN  ...    NaN    3.0      NaN
# 63200           -32.933987,-60.698261 -32.933987  ...    NaN    3.0      NaN
# 34926           -38.416097,-63.616672 -38.416097  ...    NaN    NaN      NaN
# 59181         -34.6131617,-58.4301307 -34.613162  ...    NaN    4.0      NaN
# 14572         -34.5976773,-58.4132143 -34.597677  ...    NaN    NaN   1800.0
# 42203         -34.4112671,-58.8488172 -34.411267  ...    NaN    3.0      NaN
# 41629         -27.4143938,-55.9185081 -27.414394  ...    NaN    NaN      NaN
# 104289                            NaN        NaN  ...    NaN    NaN      NaN
# 55981         -34.5669681,-58.4723408 -34.566968  ...    6.0    2.0      NaN
# 108633                            NaN        NaN  ...    NaN    NaN      NaN
# 37003   -34.6554738164,-58.5236600804 -34.655474  ...    NaN    2.0      NaN
# 50063   -34.9127421004,-57.9555857068 -34.912742  ...    NaN    3.0      NaN
# 71754                             NaN        NaN  ...    NaN    NaN      NaN
# 100612                            NaN        NaN  ...    NaN    NaN      NaN
# 467             -31.601803,-60.670345 -31.601803  ...    NaN    6.0      NaN
# 64961                             NaN        NaN  ...    NaN    NaN   4200.0
# 97696                             NaN        NaN  ...    NaN    NaN      NaN
# 92022                             NaN        NaN  ...    NaN    NaN   1000.0
# 9532          -38.0241737,-57.5626364 -38.024174  ...    NaN    4.0      NaN
# 115370          -31.406667,-64.198164 -31.406667  ...    NaN    3.0      NaN
# 119538  -37.3322524855,-57.0243550837 -37.332252  ...    NaN    6.0      NaN
# 69900                             NaN        NaN  ...    NaN    NaN      NaN
# 71259                             NaN        NaN  ...    NaN    NaN      NaN
# 94664                             NaN        NaN  ...    NaN    NaN      NaN
# 97469                             NaN        NaN  ...    NaN    NaN      NaN
# 109626          -34.516221,-58.495635 -34.516221  ...    3.0    4.0      NaN
# 82849                             NaN        NaN  ...    NaN    NaN      NaN
# 53761          -38.006242,-57.5624367 -38.006242  ...    NaN    4.0      NaN
# 61609           -34.492624,-58.733263 -34.492624  ...    NaN    3.0      NaN
# 78263         -34.5728025,-58.7208028 -34.572803  ...    NaN    NaN      NaN
# 38515         -34.5754268,-58.4840886 -34.575427  ...    NaN    2.0      NaN
# 47710           -34.435231,-59.011002 -34.435231  ...    NaN    7.0      NaN
# 24486           -34.500145,-58.516859 -34.500145  ...    NaN    5.0      NaN
# 74763                             NaN        NaN  ...    NaN    NaN      NaN
# 86508                             NaN        NaN  ...    NaN    NaN      NaN
# 99997                             NaN        NaN  ...    NaN    NaN      NaN
# 105072                            NaN        NaN  ...    NaN    NaN      NaN
# 99629                             NaN        NaN  ...    NaN    NaN      NaN
# 32922           -34.653469,-58.508671 -34.653469  ...    NaN    1.0      NaN
# 98464                             NaN        NaN  ...    NaN    NaN      NaN
# 18404         -37.9692604,-57.6201237 -37.969260  ...    NaN    5.0      NaN
# 67746                             NaN        NaN  ...    NaN    NaN      NaN
# 70516                             NaN        NaN  ...    NaN    NaN   3600.0
# 56906         -38.0023374,-57.5478082 -38.002337  ...    NaN    1.0      NaN
# 74199                             NaN        NaN  ...    NaN    NaN      NaN
# 32775         -32.9402911,-60.6645061 -32.940291  ...    NaN    1.0      NaN
# 38912         -34.6620704,-58.5131653 -34.662070  ...    NaN    2.0      NaN
# 121035                            NaN        NaN  ...    NaN    NaN      NaN
# 40168          -38.008608,-57.5798317 -38.008608  ...    NaN    4.0      NaN
# 54463                             NaN        NaN  ...    NaN    NaN      NaN
#
#                                             properati_url  \
# 26456   http://www.properati.com.ar/17r4d_venta_depart...
# 63200   http://www.properati.com.ar/1a8dq_venta_casa_r...
# 34926   http://www.properati.com.ar/18d29_venta_depart...
# 59181   http://www.properati.com.ar/19x12_venta_depart...
# 14572   http://www.properati.com.ar/16slo_venta_depart...
# 42203   http://www.properati.com.ar/18vzh_venta_depart...
# 41629   http://www.properati.com.ar/18unf_venta_casa_p...
# 104289  http://www.properati.com.ar/1bt53_venta_ph_lom...
# 55981   http://www.properati.com.ar/19pye_venta_depart...
# 108633  http://www.properati.com.ar/1c0pc_venta_ph_la-...
# 37003   http://www.properati.com.ar/18i5x_venta_depart...
# 50063   http://www.properati.com.ar/19dcw_venta_ph_la-...
# 71754   http://www.properati.com.ar/1aldm_venta_depart...
# 100612  http://www.properati.com.ar/1bo7m_venta_casa_m...
# 467     http://www.properati.com.ar/15eot_venta_casa_s...
# 64961   http://www.properati.com.ar/1abj3_venta_depart...
# 97696   http://www.properati.com.ar/1bkge_venta_depart...
# 92022   http://www.properati.com.ar/1bcbs_venta_depart...
# 9532    http://www.properati.com.ar/164mt_venta_casa_m...
# 115370  http://www.properati.com.ar/1cb47_venta_depart...
# 119538  http://www.properati.com.ar/1cgs2_venta_casa_m...
# 69900   http://www.properati.com.ar/1aiti_venta_casa_a...
# 71259   http://www.properati.com.ar/1akq2_venta_casa_v...
# 94664   http://www.properati.com.ar/1bfxj_venta_ph_pal...
# 97469   http://www.properati.com.ar/1bk3x_venta_depart...
# 109626  http://www.properati.com.ar/1c2g6_venta_depart...
# 82849   http://www.properati.com.ar/1azro_venta_depart...
# 53761   http://www.properati.com.ar/19lyz_venta_casa_m...
# 61609   http://www.properati.com.ar/1a5uv_venta_casa_l...
# 78263   http://www.properati.com.ar/1atx9_venta_casa_m...
# 38515   http://www.properati.com.ar/18l9i_venta_depart...
# 47710   http://www.properati.com.ar/198vp_venta_casa_l...
# 24486   http://www.properati.com.ar/17o8w_venta_casa_m...
# 74763   http://www.properati.com.ar/1apet_venta_casa_l...
# 86508   http://www.properati.com.ar/1b4i4_venta_depart...
# 99997   http://www.properati.com.ar/1bnbv_venta_depart...
# 105072  http://www.properati.com.ar/1bu4m_venta_casa_a...
# 99629   http://www.properati.com.ar/1bmv9_venta_depart...
# 32922   http://www.properati.com.ar/187wa_venta_local_...
# 98464   http://www.properati.com.ar/1bljz_venta_depart...
# 18404   http://www.properati.com.ar/17628_venta_casa_m...
# 67746   http://www.properati.com.ar/1afr4_venta_casa_c...
# 70516   http://www.properati.com.ar/1ajni_venta_casa_s...
# 56906   http://www.properati.com.ar/19rv0_venta_depart...
# 74199   http://www.properati.com.ar/1aonx_venta_casa_b...
# 32775   http://www.properati.com.ar/187lw_venta_depart...
# 38912   http://www.properati.com.ar/18mjd_venta_depart...
# 121035  http://www.properati.com.ar/1cj0i_venta_depart...
# 40168   http://www.properati.com.ar/18qti_venta_casa_m...
# 54463   http://www.properati.com.ar/19n15_venta_casa_b...
#
#                                               description  \
# 26456   3 ambientes al frente sobre la calle Obrero Nu...
# 63200   Corredor Responsable: Rosana Gerosa - CI Mat. ...
# 34926   CODIGO: 1780-BI 0493 ubicado en: [B.I .0493] G...
# 59181   4   amb muy luminoso ,con baulera y cochera fi...
# 14572   CODIGO: 3016-WP0217 ubicado en: Sanchez De Bus...
# 42203   Superficie total: 96.5 mtrs. Superficie cubier...
# 41629   CASA NUEVA  , SOBRE AVENIDA ASFALTADA, CONSTRU...
# 104289  P.H. en planta alta. Consta de hall de entrada...
# 55981   Venta de Departamento 2 AMBIENTES en Belgrano,...
# 108633  PH con Agua Corriente, La Plata, La Plata, por...
# 37003   DPTOS SEMIPISOS DE 2 AMB DE CATEGORIA EN CONST...
# 50063   Departamento 2 DORMITORIOS en La Plata, La Pla...
# 71754   En el residencial barrio de Villa del Parque ,...
# 100612  EXCELENTES Y UNICOS DUPLEX A ESTRENAR 8 C/AV 6...
# 467     Corredor Responsable: Marcos Provvidenti - CCI...
# 64961   EXCELENTE !!! Departamento EXTERNO CON BALCÓN ...
# 97696   Departamento Las Piedras, Nordelta/ ANTICIPO Y...
# 92022   DEPARTAMENTO  DE 2 AMBIENTES A ESTRENAR CON CO...
# 9532    Chalet en Chauvín. Living, Comedor diario, coc...
# 115370  Excelente departamento "externo" ubicado en ca...
# 119538  Venta de Casa 6 AMBIENTES, Mar de las PampasES...
# 69900   EXCELENTE CHALET COMPUESTO DE DOS DORMITORIOS ...
# 71259   Casa con Electricidad, Buenos Aires Costa Atlá...
# 94664   Excelente planta alta con entrada independient...
# 97469   Vendo o alquilo departamento en zona Molas Lóp...
# 109626  Corredor Responsable: Uno Bienes Raices SRL - ...
# 82849   DEPTO cuenta con un dormitorio  con pisos flot...
# 53761   IMPECABLE CHALET 4 AMB.PISCINA. GARAGE.chalet ...
# 61609   Corredor Responsable: Uno Bienes Raices SRL - ...
# 78263   Venta de Chalet de 4 ambientes en Las Acacias,...
# 38515   Emprendimiento de lujo, en dos de las avenidas...
# 47710   Corredor Responsable: Lucrecia Saulle - CSI 55...
# 24486   Venta - Casa - Argentina, Buenos Aires, Zona N...
# 74763   Hermosa casa en el exclusivo barrio Santa Marí...
# 86508   En Ayres Vila, con una vista insuperable  al p...
# 99997   LAS FRESIAS GARDEN - VILLA DEL PARQUE Hermosa ...
# 105072  Excelente casa en muy buena zona de Adrogue, d...
# 99629   Sergio Villella Inmobiliaria presenta departam...
# 32922   Venta - Local - Argentina, Buenos Aires, Capit...
# 98464   Sergio Villella Inmobiliaria presenta departam...
# 18404   Excelente chalet de 5 amb. Estilo Marplantense...
# 67746   Te invitamos a conocer:En barrio cerrado Corra...
# 70516   Hermosa propiedad de concepto moderno, muy bie...
# 56906   Departamento de un ambiente y medio ubicado en...
# 74199   UBICADO SOBRE LA CALLE INT.ALVARO PINTOS Nº 1....
# 32775   Edificio de diseño en la mejor zona para inver...
# 38912   Edificio  en construcción de 4 pisos, 9 unidad...
# 121035  Torre de 16º pisos ubicado en pleno centro com...
# 40168   Chalet 4 ambientes a reciclar. Lote de 10 x 43...
# 54463   Lote en esquina ingreso por calle Libertad, de...
#
#                                                     title  \
# 26456                        Almagro 3 ambientes c/balcon
# 63200     Casa 2 dorm, con cochera y patio. Apto crédito.
# 34926   [B.I .0493] HERMOSO DEPARTAMENTO DE 3 AMB. EN ...
# 59181   Departamento de 4 ambientes en Venta en Caballito
# 14572    Amplio dos ambientes a estrenar en pleno Palermo
# 42203   AMPLIO DPTO DE TRES AMBIENTES CON COCHERA EN C...
# 41629                     CASA ZONA BARRIO INDEPENDENCIA
# 104289                               PH - Lomas De Zamora
# 55981                               DEPARTAMENTO EN VENTA
# 108633                                      PH - La Plata
# 37003   2 AMB A ESTRENAR CON BALCON TERRAZA, A MTS DE ...
# 50063                                         PH EN VENTA
# 71754   Confort Lascano- Lascano 3426 dptos 1 amb a es...
# 100612                      Casa - Mart.-Santa Fe/Fleming
# 467     CASA Y TERRENO GUADALUPE APTA A CRÉDITO CON PATIO
# 64961   ESPECTACULAR!!!!  OPERA LUXURY..2DOR-2COCHE-EX...
# 97696                               Departamento en venta
# 92022   VENTA-DEPARTAMENTO  2 AMBIENTES A ESTRENAR C/C...
# 9532                                    Chalet en Chauvín
# 115370             EXCELENTE DEPARTAMENTO - LA RIOJA 1180
# 119538                                      CASA EN VENTA
# 69900                                                   .
# 71259                             Casa en Valeria del Mar
# 94664                        Guatemala 4100- PH - Palermo
# 97469                       Departamento - Las Carmelitas
# 109626  Depto en Venta en Olivos, Ugarte 2016. 4 amb./...
# 82849      Departamento  APTO BANCO en diag 73 e/ 24 y 25
# 53761   IMPERDIBLE CHALET 4 AMB.MAS DEPCIA, GARAGE, PI...
# 61609      Duplex 3 ambientes -  Apto Credito Hipotecario
# 78263                                       CASA EN VENTA
# 38515    Un nuevo icono en Villa Urquiza- Evoque Olazabal
# 47710     VENTA CASA EN LA ESCONDIDA DE MANZANARES, PILAR
# 24486                   Casa en Venta ubicado en Martínez
# 74763              Casa en Santa María de Lobos Polo Club
# 86508                             Departamento - Del Viso
# 99997                     Departamento - Villa del Parque
# 105072                                     Casa - Adrogue
# 99629    Paraguay 2200 - Venta departamento un dormitorio
# 32922                 Local en Venta ubicado en Mataderos
# 98464                          Departamento - Macrocentro
# 18404                  Chalet 5 amb.  Barrio Stella Maris
# 67746   ***Viví Corral de Barrancas, barrio cerrado, 3...
# 70516                    Hermosa casa en Solar del Bosque
# 56906                           venta 1 ambiente y medio
# 74199                                      Casa - Burzaco
# 32775   SANTA FE 3000 FRENTE FACULTAD DE MEDICINA, a e...
# 38912   Departamentos 2 amb en pozo 45m2 al frente Mat...
# 121035                          Departamento - Belgrano C
# 40168                                 Chalet 4 ambientes
# 54463    Bustamante Propiedades - Venta Casa en Benavidez
#
#                                           image_thumbnail  \
# 26456   https://thumbs4.properati.com/8/HmCMabG4zMtKDA...
# 63200   https://thumbs4.properati.com/5/XE82ezZR2Oi3Fu...
# 34926   https://thumbs4.properati.com/5/Bqbz024u6F2fxn...
# 59181   https://thumbs4.properati.com/2/7-RiJZ_lLT2mdO...
# 14572   https://thumbs4.properati.com/3/cNIrfEqeMzd5gx...
# 42203   https://thumbs4.properati.com/3/Z_dA5jowjB86m-...
# 41629   https://thumbs4.properati.com/7/tPaoQSzC9-CPHs...
# 104289  https://thumbs4.properati.com/2/9hJQyocxiSoY_D...
# 55981   https://thumbs4.properati.com/2/hDcdYeO6FGZLWc...
# 108633  https://thumbs4.properati.com/5/Cr5_ot1O5fqHgw...
# 37003   https://thumbs4.properati.com/4/7Iy1lAO-D2wQ7Q...
# 50063   https://thumbs4.properati.com/2/M45hdzm16os2Ff...
# 71754   https://thumbs4.properati.com/6/YqlxH1isae0Rq4...
# 100612  https://thumbs4.properati.com/3/xKMd80XQHomNdg...
# 467     https://thumbs4.properati.com/2/jbAfwSeNfI_Hym...
# 64961   https://thumbs4.properati.com/1/7FpJzGjImyeXKO...
# 97696   https://thumbs4.properati.com/7/3uUoYpqTMjNgaa...
# 92022   https://thumbs4.properati.com/4/Tqj9XOkqvftg4R...
# 9532    https://thumbs4.properati.com/6/Fd0T-U4YWSfvG-...
# 115370  https://thumbs4.properati.com/6/g_sVomhzT6SopW...
# 119538  https://thumbs4.properati.com/1/kHkn_PmdpF8qOt...
# 69900   https://thumbs4.properati.com/5/nDq2Uwx3ZfAe0E...
# 71259   https://thumbs4.properati.com/5/9S5ilkaHSuLxm6...
# 94664   https://thumbs4.properati.com/0/t9Kzxpw01AbGSJ...
# 97469   https://thumbs4.properati.com/3/lnAHR4fjzuvVY0...
# 109626  https://thumbs4.properati.com/5/sb5n8b8o9eoebM...
# 82849   https://thumbs4.properati.com/5/vQAiHFVfSbSiea...
# 53761   https://thumbs4.properati.com/4/Ri8mUxZnFDlN8I...
# 61609   https://thumbs4.properati.com/0/RdrQkJDcjSVBkb...
# 78263   https://thumbs4.properati.com/6/6z5oqA0QWxQhk9...
# 38515   https://thumbs4.properati.com/1/lDsVzJYJKWwFSO...
# 47710   https://thumbs4.properati.com/8/lYsZdfINrxC_af...
# 24486   https://thumbs4.properati.com/4/u6d_EGdlIdxbpd...
# 74763   https://thumbs4.properati.com/6/-bWONY7szw8F08...
# 86508   https://thumbs4.properati.com/5/fKdCAKXOYdreIQ...
# 99997   https://thumbs4.properati.com/3/ujgbfYc7q4IVwI...
# 105072  https://thumbs4.properati.com/4/4DtjJZNbQuJwJK...
# 99629   https://thumbs4.properati.com/9/yADEonPzOBQD73...
# 32922   https://thumbs4.properati.com/6/ISF8bYMt7U6XlE...
# 98464   https://thumbs4.properati.com/3/RWOVGE9UumB7tQ...
# 18404   https://thumbs4.properati.com/0/1SH8B1CgesBcLL...
# 67746   https://thumbs4.properati.com/5/wSE2eBO-U0WThE...
# 70516   https://thumbs4.properati.com/4/tqxTDHoIoVrQt0...
# 56906   https://thumbs4.properati.com/6/35MXCkQtIwSPWj...
# 74199   https://thumbs4.properati.com/8/TZLQHdbetsX2bE...
# 32775   https://thumbs4.properati.com/4/cmzNApHqbH5f4Y...
# 38912   https://thumbs4.properati.com/0/E737t_QpKnQ83k...
# 121035  https://thumbs4.properati.com/3/j59brF44j7AX_c...
# 40168   https://thumbs4.properati.com/6/POKcQU-qGe89Cm...
# 54463   https://thumbs4.properati.com/6/E0cV2fRUW7fcjg...
#
#               ciudad_separada  precio_unificado  superficie_unificada
# 26456                 Almagro       2410.714286                  56.0
# 63200                 Rosario       1640.625000                  64.0
# 34926   Buenos Aires Interior       1557.976514                  59.0
# 59181               Caballito       2275.000000                  80.0
# 14572                 Palermo       3129.629630                  54.0
# 42203                   Pilar       2319.587629                  97.0
# 41629                 Posadas        115.672575                 800.0
# 104289        Lomas de Zamora       1375.724533                   NaN
# 55981                Belgrano       2864.406780                  59.0
# 108633               La Plata       1008.064516                 124.0
# 37003                 Liniers       2083.333333                  72.0
# 50063                La Plata       1263.736264                  91.0
# 71754        Villa del Parque       2142.857143                  42.0
# 100612             San Isidro       2000.000000                 185.0
# 467                  Santa Fe      12495.902991                   NaN
# 64961                 Córdoba       7890.329350                 110.0
# 97696                   Tigre      58314.476744                  86.0
# 92022                   Morón       2500.000000                  46.0
# 9532            Mar del Plata        683.760684                 234.0
# 115370                Córdoba       7890.329350                   NaN
# 119538      Mar de las Pampas       1000.000000                 450.0
# 69900         Almirante Brown       1250.000000                 120.0
# 71259         Valeria del Mar       1600.000000                 100.0
# 94664                 Palermo       1878.453039                 362.0
# 97469               Mburucuyá       2257.866452                   NaN
# 109626          Vicente López       2731.481481                 108.0
# 82849                La Plata       1215.146167                  60.0
# 53761           Mar del Plata        812.608619                 333.0
# 61609     Malvinas Argentinas       3825.000000                  20.0
# 78263              San Miguel        289.761751                1553.0
# 38515           Villa Urquiza       3850.705486                  58.0
# 47710                   Pilar       1564.285714                 280.0
# 24486              San Isidro       1678.571429                 140.0
# 74763                   Lobos       1076.709200                1300.0
# 86508                   Pilar       1973.948167                  60.0
# 99997        Villa del Parque       2546.875000                  96.0
# 105072        Almirante Brown       1733.333333                 150.0
# 99629                 Rosario       1777.971702                  47.0
# 32922               Mataderos       1641.025361                   NaN
# 98464                 Rosario       6182.049730                  40.0
# 18404           Mar del Plata        812.608619                   NaN
# 67746                 Córdoba       5046.748599                   NaN
# 70516                  Ezeiza       1587.372554                 330.0
# 56906           Mar del Plata       1833.333333                  30.0
# 74199         Almirante Brown       1476.463371                   NaN
# 32775                 Rosario       6182.049730                  45.0
# 38912               Mataderos       1666.666667                  45.0
# 121035               Belgrano       3706.368451                  46.0
# 40168           Mar del Plata        277.136259                 433.0
# 54463                   Tigre       1365.517241                 145.0
#
# [50 rows x 29 columns]

# %% [markdown]
# # Indicadores de limpieza

# %%
print("Cant. de nulos en surface_total_in_m2 iniciales:   %", (data.surface_total_in_m2.isnull().sum() / data.shape[0]*100).round(2))
print("Cant. de nulos en surface_covered_in_m2 iniciales:   %", (data.surface_covered_in_m2.isnull().sum() / data.shape[0]*100).round(2))
print("Cant. de nulos en superficie_unificada finales:   %", (salida_5.superficie_unificada.isnull().sum() / salida_5.shape[0]*100).round(2))
# Out:
# Cant. de nulos en surface_total_in_m2 iniciales:   % 32.44
# Cant. de nulos en surface_covered_in_m2 iniciales:   % 16.42
# Cant. de nulos en superficie_unificada finales:   % 10.52

# %%
print("Cant. de nulos en price_usd_per_m2 iniciales:   %", (data.price_usd_per_m2.isnull().sum() / data.shape[0]*100).round(2))
print("Cant. de nulos en precio_unificado finales:   %", (salida_5.precio_unificado.isnull().sum() / salida_5.shape[0]*100).round(2))
# Out:
# Cant. de nulos en price_usd_per_m2 iniciales:   % 43.39
# Cant. de nulos en precio_unificado finales:   % 0.43
